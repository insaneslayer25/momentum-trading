# %%
import yfinance as yf
import pandas as pd

alpha_data = pd.read_csv('combined_alpha.csv')
index_data = pd.read_csv('total_index_ticker_marketcap.csv')

START_DATE = '2024-06-03'
END_DATE = '2024-11-19'

# %%
midcap_index = pd.read_csv('data/historic_data/Nifty_Midcap_150.csv')
smallcap_index = pd.read_csv('data/historic_data/Nifty_Smallcap_250.csv')
midcap_index['Price'] = midcap_index['Price'].replace(',', '', regex=True).astype(float)
smallcap_index['Price'] = smallcap_index['Price'].replace(',', '', regex=True).astype(float)

nifty50 = yf.Ticker('^NSEI').history(start=START_DATE,end=END_DATE)
nifty50_return = ((nifty50['Close'].iloc[-1] - nifty50['Close'].iloc[0])/ nifty50['Close'].iloc[0]) * 100

midcap_start = float(midcap_index[midcap_index['Date']=='03-06-2024']['Price'].iloc[0])
midcap_end = float(midcap_index.iloc[0]['Price'])
midcap150_return =round (((midcap_end-midcap_start)/midcap_start) * 100,2)

smallcap_start = float(smallcap_index[smallcap_index['Date']=='03-06-2024']['Price'].iloc[0])
smallcap_end = float(midcap_index.iloc[0]['Price'])
smallcap250_return = round(((smallcap_end-smallcap_start)/smallcap_start)*100,2)

# %%
data = pd.merge(alpha_data,index_data[['Ticker','Market Cap']],on='Ticker',how='left')
print(data)
# Out:
#                           Company Name         Ticker      NSE Symbol  \
# 0                       ABB India Ltd.         ABB.NS         NSE:ABB
# 1                     Adani Power Ltd.  ADANIPOWER.NS  NSE:ADANIPOWER
# 2        Aditya Birla Real Estate Ltd.       ABREL.NS       NSE:ABREL
# 3    Amara Raja Energy & Mobility Ltd.       ARE&M.NS       NSE:ARE&M
# 4                 Apar Industries Ltd.    APARINDS.NS    NSE:APARINDS
# ..                                 ...            ...             ...
# 61                        Siemens Ltd.     SIEMENS.NS     NSE:SIEMENS
# 62  Sun Pharmaceutical Industries Ltd.   SUNPHARMA.NS   NSE:SUNPHARMA
# 63                    Tata Motors Ltd.  TATAMOTORS.NS  NSE:TATAMOTORS
# 64        Torrent Pharmaceuticals Ltd.  TORNTPHARM.NS  NSE:TORNTPHARM
# 65                        Vedanta Ltd.        VEDL.NS        NSE:VEDL
#
#    Market Cap
# 0   Large Cap
# 1   Large Cap
# 2   Small Cap
# 3   Small Cap
# 4   Small Cap
# ..        ...
# 61  Large Cap
# 62  Large Cap
# 63  Large Cap
# 64  Large Cap
# 65  Large Cap
#
# [66 rows x 4 columns]

# %%
def calulate_return(ticker,period):
    stock = yf.Ticker(ticker).history(period=period)

    if not stock.empty:
        start_price = stock['Close'].iloc[0]
        last_price = stock['Close'].iloc[-1]
        returns = round(((last_price-start_price)/start_price)*100, 2)
        print(f'{ticker} has given {returns} return in last {period}')
        return float(returns)

    else:
        print(f'{ticker} does not have enough data for given period {period}')
        return None

# %%
def calculate_absolute_momentum(ticker, start_date=None, end_date=None, period=None):

    if (start_date is None or end_date is None) and period is None:
        print('Provide either period or both start date and end date')
        return None

    try:
        if period:
            stock = yf.Ticker(ticker).history(period=period)
        else:
            stock = yf.Ticker(ticker).history(start=start_date, end=end_date)

        if not stock.empty:
            start_price = stock['Close'].iloc[0]
            last_price = stock['Close'].iloc[-1]
            absolute_momentum_score = last_price/start_price
            print(f'{ticker} has absolute momentum score of {
                  absolute_momentum_score}')
            return round(float(absolute_momentum_score), 4)
        else:
            print(f'{ticker} does not have enough data')
            return None

    except Exception as e:
        print(f"Error calculating absolute momentum: {str(e)}")
        return None


def calculate_relative_momentum(ticker, market_cap, start_date=None, end_date=None, period=None):
    if (start_date is None or end_date is None) and period is None:
        print('Provide either period or both start date and end date')
        return None

    market_cap_ticker = {
        'Large Cap': nifty50_return,
        'Mid Cap': midcap150_return,
        'Small Cap': smallcap250_return,
    }

    if market_cap not in market_cap_ticker:
        print("Invalid market cap category. Choose from: 'Large Cap', 'Mid Cap', 'Small Cap', 'Micro Cap'.")
        return None

    try:

        if period:
            stock_data = yf.Ticker(ticker).history(period=period)
        else:
            stock_data = yf.Ticker(ticker).history(
                start=start_date, end=end_date)
            

        if stock_data.empty:
            print(f"Data is not available for {ticker} in the given period.")
            return None

        stock_start_price = stock_data['Close'].iloc[0]
        stock_end_price = stock_data['Close'].iloc[-1]
        stock_return = ((stock_end_price - stock_start_price) /
                        stock_start_price) * 100

        index_return = market_cap_ticker[market_cap]

        if index_return == 0:
            print("Warning: Index return is zero, cannot calculate relative momentum")
            return None

        relative_momentum = stock_return/index_return
        print(f'{ticker} has relative momentum score of {relative_momentum}')
        return round(float(relative_momentum), 4)

    except Exception as e:
        print(f"Error calculating relative momentum: {str(e)}")
        return None

def calculate_dual_momentum(ticker, market_cap, start_date=None, end_date=None, period=None,
                            absolute_momentum_weightage=50, relative_momentum_weightage=50):
    if absolute_momentum_weightage + relative_momentum_weightage != 100:
        print(f"Error: The weightages must sum to 100. Given: {
              absolute_momentum_weightage + relative_momentum_weightage}")
        return None

    try:
        relative_momentum = calculate_relative_momentum(
            ticker, market_cap, start_date, end_date, period)
        absolute_momentum = calculate_absolute_momentum(
            ticker, start_date, end_date, period)

        if relative_momentum is None or absolute_momentum is None:
            return None

        dual_momentum = (absolute_momentum * absolute_momentum_weightage) / 100 + \
            (relative_momentum * relative_momentum_weightage) / 100

        print(f'{ticker} has a dual momentum score of {dual_momentum}')
        return round(dual_momentum, 4)

    except Exception as e:
        print(f"Error calculating dual momentum: {str(e)}")
        return None

# %%
def df_relative_momentum(row):
    return calculate_relative_momentum(ticker=row['Ticker'],start_date=START_DATE,end_date=END_DATE,market_cap=row['Market Cap'])

def df_absolute_momentum(row):
    return calculate_absolute_momentum(ticker=row['Ticker'],start_date=START_DATE,end_date=END_DATE)

def df_dual_momentum(row):
    return calculate_dual_momentum(ticker=row['Ticker'],start_date=START_DATE,end_date=END_DATE,market_cap=row['Market Cap'])

# %%
data['Relative Momentum'] = data.apply(df_relative_momentum,axis=1)
data['Absolute Momentum'] = data.apply(df_absolute_momentum,axis=1)
data['Dual Momentum'] = data.apply(df_dual_momentum,axis=1)
# Out:
# ABB.NS has relative momentum score of -29.378670676564788
# ADANIPOWER.NS has relative momentum score of -48.70113940009223
# ABREL.NS has relative momentum score of 0.7796727132431704
# ARE&M.NS has relative momentum score of 0.11815974902957456
# APARINDS.NS has relative momentum score of 0.4075298355448038
# AUROPHARMA.NS has relative momentum score of 0.43164519632157283
# BSE.NS has relative momentum score of 49.50052034027351
# BAJAJ-AUTO.NS has relative momentum score of 3.3907953302419713
# BDL.NS has relative momentum score of -27.218255136765023
# BEL.NS has relative momentum score of -15.319229960351826
# BHEL.NS has relative momentum score of -34.84717156387964
# CDSL.NS has relative momentum score of 1.5305856273232776
# COCHINSHIP.NS has relative momentum score of -23.35685101717874
# COLPAL.NS has relative momentum score of 2.077445660816433
# CUMMINSIND.NS has relative momentum score of -6.100206990744205
# DIXON.NS has relative momentum score of 33.0304921157537
# GLENMARK.NS has relative momentum score of 0.9965675886415333
# HAL.NS has relative momentum score of -27.517451736332024
# HINDCOPPER.NS has relative momentum score of -1.0692507883043754
# HINDPETRO.NS has relative momentum score of -1.7538101759892584
# POWERINDIA.NS has relative momentum score of 1.7550043373542095
# HUDCO.NS has relative momentum score of -18.75428357791203
# IRFC.NS has relative momentum score of -32.005241118515634
# INDUSTOWER.NS has relative momentum score of -7.432138509481774
# INOXWIND.NS has relative momentum score of 0.8711053636868217
# JSL.NS has relative momentum score of -9.275984260410898
# KEI.NS has relative momentum score of -7.721847163405508
# KALYANKJIL.NS has relative momentum score of 47.22710078187985
# LUPIN.NS has relative momentum score of 19.262977939436276
# LODHA.NS has relative momentum score of -16.686144456123465
# MCX.NS has relative momentum score of 2.340425457827627
# NBCC.NS has relative momentum score of -0.37938034010461413
# NHPC.NS has relative momentum score of -37.44815819370181
# OIL.NS has relative momentum score of 4.572161787882534
# OFSS.NS has relative momentum score of 32.47601537584704
# POLICYBZR.NS has relative momentum score of 22.428151717920613
# PHOENIXLTD.NS has relative momentum score of -8.223543341798571
# PFC.NS has relative momentum score of -20.023692536541535
# PRESTIGE.NS has relative momentum score of -7.34965247216838
# RECLTD.NS has relative momentum score of -18.593624950546864
# RVNL.NS has relative momentum score of 2.172292153840745
# SJVN.NS has relative momentum score of -17.58522225206686
# SOLARINDS.NS has relative momentum score of -0.8508970430206331
# SUZLON.NS has relative momentum score of 12.264898439116825
# TVSMOTOR.NS has relative momentum score of 9.038206122773156
# TORNTPOWER.NS has relative momentum score of 3.139084442304823
# TRENT.NS has relative momentum score of 43.078825264325076
# VBL.NS has relative momentum score of 5.1758189474093825
# ZOMATO.NS has relative momentum score of 66.56999234258735
# ZYDUSLIFE.NS has relative momentum score of -10.11065574424695
# ADANIGREEN.NS has relative momentum score of -34.92738198668374
# BPCL.NS has relative momentum score of -12.73016655455096
# BHARTIARTL.NS has relative momentum score of 13.60283923801046
# BOSCHLTD.NS has relative momentum score of 16.214045456376468
# COALINDIA.NS has relative momentum score of -19.005251754082746
# GAIL.NS has relative momentum score of -24.06591298340465
# HEROMOTOCO.NS has relative momentum score of -9.325795138137481
# IOC.NS has relative momentum score of -24.84508558969855
# INDIGO.NS has relative momentum score of -9.170720425474732
# NTPC.NS has relative momentum score of -6.231508898837063
# MOTHERSON.NS has relative momentum score of 13.30679597605474
# SIEMENS.NS has relative momentum score of -10.674203442457816
# SUNPHARMA.NS has relative momentum score of 25.313242702063494
# TATAMOTORS.NS has relative momentum score of -22.70671387407352
# TORNTPHARM.NS has relative momentum score of 19.862206171215522
# VEDL.NS has relative momentum score of 3.7976089910753146
# ABB.NS has absolute momentum score of 0.7601854829222383
# ADANIPOWER.NS has absolute momentum score of 0.6024585198238279
# ABREL.NS has absolute momentum score of 1.207314974451359
# ARE&M.NS has absolute momentum score of 1.0314186772669638
# APARINDS.NS has absolute momentum score of 1.1083621832713633
# AUROPHARMA.NS has absolute momentum score of 1.0065178424644559
# BSE.NS has absolute momentum score of 1.74745785713813
# BAJAJ-AUTO.NS has absolute momentum score of 1.0276786500513846
# BDL.NS has absolute momentum score of 0.5890043474348482
# BEL.NS has absolute momentum score of 0.8749509882393862
# BHEL.NS has absolute momentum score of 0.7155467750015004
# CDSL.NS has absolute momentum score of 1.4069827183052594
# COCHINSHIP.NS has absolute momentum score of 0.647311549640601
# COLPAL.NS has absolute momentum score of 1.0313694294783282
# CUMMINSIND.NS has absolute momentum score of 0.9078868744397625
# DIXON.NS has absolute momentum score of 1.498760430947881
# GLENMARK.NS has absolute momentum score of 1.2649873218197838
# HAL.NS has absolute momentum score of 0.7753783868572673
# HINDCOPPER.NS has absolute momentum score of 0.7156862153898665
# HINDPETRO.NS has absolute momentum score of 0.9735174663425622
# POWERINDIA.NS has absolute momentum score of 1.0265005654940487
# HUDCO.NS has absolute momentum score of 0.7168103179735283
# IRFC.NS has absolute momentum score of 0.7387451077248124
# INDUSTOWER.NS has absolute momentum score of 0.8877747085068252
# INOXWIND.NS has absolute momentum score of 1.2316269162043259
# JSL.NS has absolute momentum score of 0.8599326376677954
# KEI.NS has absolute momentum score of 0.8834001078325768
# KALYANKJIL.NS has absolute momentum score of 1.7131292218063856
# LUPIN.NS has absolute momentum score of 1.2908709668854876
# LODHA.NS has absolute momentum score of 0.863793031390387
# MCX.NS has absolute momentum score of 1.622319129236366
# NBCC.NS has absolute momentum score of 0.8991227675661831
# NHPC.NS has absolute momentum score of 0.6943152373521785
# OIL.NS has absolute momentum score of 1.0690396429970264
# OFSS.NS has absolute momentum score of 1.4903878321752904
# POLICYBZR.NS has absolute momentum score of 1.3386650909406013
# PHOENIXLTD.NS has absolute momentum score of 0.8758244955388416
# PFC.NS has absolute momentum score of 0.8365491251826034
# PRESTIGE.NS has absolute momentum score of 0.8890202476702574
# RECLTD.NS has absolute momentum score of 0.8482225000126586
# RVNL.NS has absolute momentum score of 1.0328016115229952
# SJVN.NS has absolute momentum score of 0.7344631439937904
# SOLARINDS.NS has absolute momentum score of 0.9871514546503884
# SUZLON.NS has absolute momentum score of 1.185199966430664
# TVSMOTOR.NS has absolute momentum score of 1.0737777777777777
# TORNTPOWER.NS has absolute momentum score of 1.047400175078803
# TRENT.NS has absolute momentum score of 1.351647213407866
# VBL.NS has absolute momentum score of 1.04224958082753
# ZOMATO.NS has absolute momentum score of 1.5434027543745414
# ZYDUSLIFE.NS has absolute momentum score of 0.9174679463431191
# ADANIGREEN.NS has absolute momentum score of 0.7148920270715775
# BPCL.NS has absolute momentum score of 0.8960851980605652
# BHARTIARTL.NS has absolute momentum score of 1.111038322961022
# BOSCHLTD.NS has absolute momentum score of 1.1323532818692006
# COALINDIA.NS has absolute momentum score of 0.844862493157343
# GAIL.NS has absolute momentum score of 0.8035528780832687
# HEROMOTOCO.NS has absolute momentum score of 0.9238746680528813
# IOC.NS has absolute momentum score of 0.7971925868244935
# INDIGO.NS has absolute momentum score of 0.9251405240794391
# NTPC.NS has absolute momentum score of 0.9491328754714453
# MOTHERSON.NS has absolute momentum score of 1.108621757804564
# SIEMENS.NS has absolute momentum score of 0.9128677749948446
# SUNPHARMA.NS has absolute momentum score of 1.2066289227684466
# TATAMOTORS.NS has absolute momentum score of 0.8146478551707372
# TORNTPHARM.NS has absolute momentum score of 1.1621327742663525
# VEDL.NS has absolute momentum score of 1.0309994205071835
# ABB.NS has relative momentum score of -29.378670676564788
# ABB.NS has absolute momentum score of 0.7601854829222383
# ABB.NS has a dual momentum score of -14.309249999999999
# ADANIPOWER.NS has relative momentum score of -48.70113940009223
# ADANIPOWER.NS has absolute momentum score of 0.6024585198238279
# ADANIPOWER.NS has a dual momentum score of -24.0493
# ABREL.NS has relative momentum score of 0.7796727132431704
# ABREL.NS has absolute momentum score of 1.207314974451359
# ABREL.NS has a dual momentum score of 0.9935
# ARE&M.NS has relative momentum score of 0.11815974902957456
# ARE&M.NS has absolute momentum score of 1.0314186772669638
# ARE&M.NS has a dual momentum score of 0.5748000000000001
# APARINDS.NS has relative momentum score of 0.4075298355448038
# APARINDS.NS has absolute momentum score of 1.1083621832713633
# APARINDS.NS has a dual momentum score of 0.75795
# AUROPHARMA.NS has relative momentum score of 0.43164519632157283
# AUROPHARMA.NS has absolute momentum score of 1.0065178424644559
# AUROPHARMA.NS has a dual momentum score of 0.71905
# BSE.NS has relative momentum score of 49.50052034027351
# BSE.NS has absolute momentum score of 1.74745785713813
# BSE.NS has a dual momentum score of 25.624000000000002
# BAJAJ-AUTO.NS has relative momentum score of 3.3907953302419713
# BAJAJ-AUTO.NS has absolute momentum score of 1.0276786500513846
# BAJAJ-AUTO.NS has a dual momentum score of 2.20925
# BDL.NS has relative momentum score of -27.218255136765023
# BDL.NS has absolute momentum score of 0.5890043474348482
# BDL.NS has a dual momentum score of -13.31465
# BEL.NS has relative momentum score of -15.319229960351826
# BEL.NS has absolute momentum score of 0.8749509882393862
# BEL.NS has a dual momentum score of -7.2221
# BHEL.NS has relative momentum score of -34.84717156387964
# BHEL.NS has absolute momentum score of 0.7155467750015004
# BHEL.NS has a dual momentum score of -17.06585
# CDSL.NS has relative momentum score of 1.5305856273232776
# CDSL.NS has absolute momentum score of 1.4069827183052594
# CDSL.NS has a dual momentum score of 1.4687999999999999
# COCHINSHIP.NS has relative momentum score of -23.35685101717874
# COCHINSHIP.NS has absolute momentum score of 0.647311549640601
# COCHINSHIP.NS has a dual momentum score of -11.3548
# COLPAL.NS has relative momentum score of 2.077445660816433
# COLPAL.NS has absolute momentum score of 1.0313694294783282
# COLPAL.NS has a dual momentum score of 1.5544
# CUMMINSIND.NS has relative momentum score of -6.100206990744205
# CUMMINSIND.NS has absolute momentum score of 0.9078868744397625
# CUMMINSIND.NS has a dual momentum score of -2.59615
# DIXON.NS has relative momentum score of 33.0304921157537
# DIXON.NS has absolute momentum score of 1.498760430947881
# DIXON.NS has a dual momentum score of 17.264650000000003
# GLENMARK.NS has relative momentum score of 0.9965675886415333
# GLENMARK.NS has absolute momentum score of 1.2649873218197838
# GLENMARK.NS has a dual momentum score of 1.1308
# HAL.NS has relative momentum score of -27.517451736332024
# HAL.NS has absolute momentum score of 0.7753783868572673
# HAL.NS has a dual momentum score of -13.371049999999999
# HINDCOPPER.NS has relative momentum score of -1.0692507883043754
# HINDCOPPER.NS has absolute momentum score of 0.7156862153898665
# HINDCOPPER.NS has a dual momentum score of -0.1768
# HINDPETRO.NS has relative momentum score of -1.7538101759892584
# HINDPETRO.NS has absolute momentum score of 0.9735174663425622
# HINDPETRO.NS has a dual momentum score of -0.39015
# POWERINDIA.NS has relative momentum score of 1.7550043373542095
# POWERINDIA.NS has absolute momentum score of 1.0265005654940487
# POWERINDIA.NS has a dual momentum score of 1.39075
# HUDCO.NS has relative momentum score of -18.75428357791203
# HUDCO.NS has absolute momentum score of 0.7168103179735283
# HUDCO.NS has a dual momentum score of -9.01875
# IRFC.NS has relative momentum score of -32.005241118515634
# IRFC.NS has absolute momentum score of 0.7387451077248124
# IRFC.NS has a dual momentum score of -15.63325
# INDUSTOWER.NS has relative momentum score of -7.432138509481774
# INDUSTOWER.NS has absolute momentum score of 0.8877747085068252
# INDUSTOWER.NS has a dual momentum score of -3.27215
# INOXWIND.NS has relative momentum score of 0.8711053636868217
# INOXWIND.NS has absolute momentum score of 1.2316269162043259
# INOXWIND.NS has a dual momentum score of 1.05135
# JSL.NS has relative momentum score of -9.275984260410898
# JSL.NS has absolute momentum score of 0.8599326376677954
# JSL.NS has a dual momentum score of -4.20805
# KEI.NS has relative momentum score of -7.721847163405508
# KEI.NS has absolute momentum score of 0.8834001078325768
# KEI.NS has a dual momentum score of -3.4191999999999996
# KALYANKJIL.NS has relative momentum score of 47.22710078187985
# KALYANKJIL.NS has absolute momentum score of 1.7131292218063856
# KALYANKJIL.NS has a dual momentum score of 24.4701
# LUPIN.NS has relative momentum score of 19.262977939436276
# LUPIN.NS has absolute momentum score of 1.2908709668854876
# LUPIN.NS has a dual momentum score of 10.276950000000001
# LODHA.NS has relative momentum score of -16.686144456123465
# LODHA.NS has absolute momentum score of 0.863793031390387
# LODHA.NS has a dual momentum score of -7.91115
# MCX.NS has relative momentum score of 2.340425457827627
# MCX.NS has absolute momentum score of 1.622319129236366
# MCX.NS has a dual momentum score of 1.98135
# NBCC.NS has relative momentum score of -0.37938034010461413
# NBCC.NS has absolute momentum score of 0.8991227675661831
# NBCC.NS has a dual momentum score of 0.25984999999999997
# NHPC.NS has relative momentum score of -37.44815819370181
# NHPC.NS has absolute momentum score of 0.6943152373521785
# NHPC.NS has a dual momentum score of -18.37695
# OIL.NS has relative momentum score of 4.572161787882534
# OIL.NS has absolute momentum score of 1.0690396429970264
# OIL.NS has a dual momentum score of 2.8205999999999998
# OFSS.NS has relative momentum score of 32.47601537584704
# OFSS.NS has absolute momentum score of 1.4903878321752904
# OFSS.NS has a dual momentum score of 16.9832
# POLICYBZR.NS has relative momentum score of 22.428151717920613
# POLICYBZR.NS has absolute momentum score of 1.3386650909406013
# POLICYBZR.NS has a dual momentum score of 11.88345
# PHOENIXLTD.NS has relative momentum score of -8.223543341798571
# PHOENIXLTD.NS has absolute momentum score of 0.8758244955388416
# PHOENIXLTD.NS has a dual momentum score of -3.67385
# PFC.NS has relative momentum score of -20.023692536541535
# PFC.NS has absolute momentum score of 0.8365490321658836
# PFC.NS has a dual momentum score of -9.5936
# PRESTIGE.NS has relative momentum score of -7.34965247216838
# PRESTIGE.NS has absolute momentum score of 0.8890202476702574
# PRESTIGE.NS has a dual momentum score of -3.23035
# RECLTD.NS has relative momentum score of -18.593624950546864
# RECLTD.NS has absolute momentum score of 0.8482225000126586
# RECLTD.NS has a dual momentum score of -8.8727
# RVNL.NS has relative momentum score of 2.172292153840745
# RVNL.NS has absolute momentum score of 1.0328016115229952
# RVNL.NS has a dual momentum score of 1.60255
# SJVN.NS has relative momentum score of -17.58522225206686
# SJVN.NS has absolute momentum score of 0.7344631439937904
# SJVN.NS has a dual momentum score of -8.42535
# SOLARINDS.NS has relative momentum score of -0.8508970430206331
# SOLARINDS.NS has absolute momentum score of 0.9871514546503884
# SOLARINDS.NS has a dual momentum score of 0.06814999999999999
# SUZLON.NS has relative momentum score of 12.264898439116825
# SUZLON.NS has absolute momentum score of 1.185199966430664
# SUZLON.NS has a dual momentum score of 6.72505
# TVSMOTOR.NS has relative momentum score of 9.038206122773156
# TVSMOTOR.NS has absolute momentum score of 1.0737777777777777
# TVSMOTOR.NS has a dual momentum score of 5.056
# TORNTPOWER.NS has relative momentum score of 3.139084442304823
# TORNTPOWER.NS has absolute momentum score of 1.047400175078803
# TORNTPOWER.NS has a dual momentum score of 2.0932500000000003
# TRENT.NS has relative momentum score of 43.078825264325076
# TRENT.NS has absolute momentum score of 1.351647213407866
# TRENT.NS has a dual momentum score of 22.2152
# VBL.NS has relative momentum score of 5.1758189474093825
# VBL.NS has absolute momentum score of 1.04224958082753
# VBL.NS has a dual momentum score of 3.1089999999999995
# ZOMATO.NS has relative momentum score of 66.56999234258735
# ZOMATO.NS has absolute momentum score of 1.5434027543745414
# ZOMATO.NS has a dual momentum score of 34.0567
# ZYDUSLIFE.NS has relative momentum score of -10.11065574424695
# ZYDUSLIFE.NS has absolute momentum score of 0.9174679463431191
# ZYDUSLIFE.NS has a dual momentum score of -4.5966
# ADANIGREEN.NS has relative momentum score of -34.92738198668374
# ADANIGREEN.NS has absolute momentum score of 0.7148920270715775
# ADANIGREEN.NS has a dual momentum score of -17.10625
# BPCL.NS has relative momentum score of -12.73016655455096
# BPCL.NS has absolute momentum score of 0.8960851980605652
# BPCL.NS has a dual momentum score of -5.91705
# BHARTIARTL.NS has relative momentum score of 13.60283923801046
# BHARTIARTL.NS has absolute momentum score of 1.111038322961022
# BHARTIARTL.NS has a dual momentum score of 7.3569
# BOSCHLTD.NS has relative momentum score of 16.214045456376468
# BOSCHLTD.NS has absolute momentum score of 1.1323532818692006
# BOSCHLTD.NS has a dual momentum score of 8.6732
# COALINDIA.NS has relative momentum score of -19.005251754082746
# COALINDIA.NS has absolute momentum score of 0.8448624404581274
# COALINDIA.NS has a dual momentum score of -9.0802
# GAIL.NS has relative momentum score of -24.06591298340465
# GAIL.NS has absolute momentum score of 0.8035528780832687
# GAIL.NS has a dual momentum score of -11.631150000000002
# HEROMOTOCO.NS has relative momentum score of -9.325795138137481
# HEROMOTOCO.NS has absolute momentum score of 0.9238746680528813
# HEROMOTOCO.NS has a dual momentum score of -4.20095
# IOC.NS has relative momentum score of -24.84508558969855
# IOC.NS has absolute momentum score of 0.7971925868244935
# IOC.NS has a dual momentum score of -12.02395
# INDIGO.NS has relative momentum score of -9.170720425474732
# INDIGO.NS has absolute momentum score of 0.9251405240794391
# INDIGO.NS has a dual momentum score of -4.1228
# NTPC.NS has relative momentum score of -6.231508898837063
# NTPC.NS has absolute momentum score of 0.9491329504424288
# NTPC.NS has a dual momentum score of -2.6411999999999995
# MOTHERSON.NS has relative momentum score of 13.30679597605474
# MOTHERSON.NS has absolute momentum score of 1.108621757804564
# MOTHERSON.NS has a dual momentum score of 7.207700000000001
# SIEMENS.NS has relative momentum score of -10.674203442457816
# SIEMENS.NS has absolute momentum score of 0.9128677749948446
# SIEMENS.NS has a dual momentum score of -4.88065
# SUNPHARMA.NS has relative momentum score of 25.313242702063494
# SUNPHARMA.NS has absolute momentum score of 1.2066289227684466
# SUNPHARMA.NS has a dual momentum score of 13.259899999999998
# TATAMOTORS.NS has relative momentum score of -22.70671387407352
# TATAMOTORS.NS has absolute momentum score of 0.8146478551707372
# TATAMOTORS.NS has a dual momentum score of -10.946050000000001
# TORNTPHARM.NS has relative momentum score of 19.862206171215522
# TORNTPHARM.NS has absolute momentum score of 1.1621327742663525
# TORNTPHARM.NS has a dual momentum score of 10.51215
# VEDL.NS has relative momentum score of 3.7976089910753146
# VEDL.NS has absolute momentum score of 1.0309994205071835
# VEDL.NS has a dual momentum score of 2.4143

# %%
data
# Out:
#                           Company Name         Ticker      NSE Symbol  \
# 0                       ABB India Ltd.         ABB.NS         NSE:ABB
# 1                     Adani Power Ltd.  ADANIPOWER.NS  NSE:ADANIPOWER
# 2        Aditya Birla Real Estate Ltd.       ABREL.NS       NSE:ABREL
# 3    Amara Raja Energy & Mobility Ltd.       ARE&M.NS       NSE:ARE&M
# 4                 Apar Industries Ltd.    APARINDS.NS    NSE:APARINDS
# ..                                 ...            ...             ...
# 61                        Siemens Ltd.     SIEMENS.NS     NSE:SIEMENS
# 62  Sun Pharmaceutical Industries Ltd.   SUNPHARMA.NS   NSE:SUNPHARMA
# 63                    Tata Motors Ltd.  TATAMOTORS.NS  NSE:TATAMOTORS
# 64        Torrent Pharmaceuticals Ltd.  TORNTPHARM.NS  NSE:TORNTPHARM
# 65                        Vedanta Ltd.        VEDL.NS        NSE:VEDL
#
#    Market Cap  Relative Momentum  Absolute Momentum  Dual Momentum
# 0   Large Cap           -29.3787             0.7602       -14.3092
# 1   Large Cap           -48.7011             0.6025       -24.0493
# 2   Small Cap             0.7797             1.2073         0.9935
# 3   Small Cap             0.1182             1.0314         0.5748
# 4   Small Cap             0.4075             1.1084         0.7580
# ..        ...                ...                ...            ...
# 61  Large Cap           -10.6742             0.9129        -4.8807
# 62  Large Cap            25.3132             1.2066        13.2599
# 63  Large Cap           -22.7067             0.8146       -10.9461
# 64  Large Cap            19.8622             1.1621        10.5122
# 65  Large Cap             3.7976             1.0310         2.4143
#
# [66 rows x 7 columns]

# %%
data.to_csv('momentum_stocks.csv',index=False)
